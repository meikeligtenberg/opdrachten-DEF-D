# %% [markdown]
# # Condensator Ontwerpopdracht
#
# Bij het vak elektromagnetisme zullen jullie in de eerste paar weken diep ingaan op de elektrostatica. Parallel hieraan zullen we bij het vak DEF-D, naast de fysieke ontwerpopdrachten en colleges, deze simulatie-ontwerpopdracht behandelen. Deze simulatie-opdracht is weer nauw verwoven met de tweede fysieke ontwerpopdracht die in week 3.3 gegeven wordt. Je moet het grootste deel van deze simulatie opdracht afronden voordat je aan de fysieke ontwerpopdracht van week 3.3 begint. Het laatste stuk van deze simulatie opdracht maak je na afloop van de fysieke opdracht. De deadline voor het inleveren van deze simulatie-opdracht is in week 3.4
#
# Je werkt bij deze opdracht in teams die wij indelen. Zoek op Brightspace op met wie je samenwerkt en leg via email contact. Maak goede afspraken over hoe je samen gaat werken.
#
# In deze simulatie opdracht beginnen we met een aantal simulaties van verschillende situaties, die jullie daarna zullen interpreteren. Daarna zal wat essentiële voorbereiding op de tweede fysieke ontwerpopdracht besproken worden. En als laatste zal dieper ingegaan worden op hoe jullie metingen van de tweede ontwerpopdracht afwijken van de theorie.
#
# De opdracht bestaat uit de volgende sub-opdrachten die je moet doen voordat je begint aan de fysieke ontwerpopdracht van week 3.3:
# 1) Een puntlading in de oorsprong.
# 2) Een uniform geladen schijf bestaande uit puntladingen.
# 3) Een geladen schijf op een constant potentiaal.
# 4) Twee geleidende platen op potentiaal $V_1$ and $-V_1$.
# 5) Voorbereidende opdracht voor de DEF ontwerpopdracht.
#
# Na de fysieke ontwerpopdracht van week 3.3 kan je ten slotte het laatste deel doen:
#
# 6) Reflectie opdracht voor na de fysieke ontwerpopdracht.
#
# De opdracht wordt volledig online gedaan, er zullen hiervoor dus ook geen specifieke werkcolleges voor zijn ingeroosterd. Als jullie vragen hebben kunnen jullie die mailen naar het DEF e-mailadres: DEF-TNW@tudelft.nl. Deze opdracht wordt in week 3.4 beoordeeld en herkansingen zijn in week 3.5, zie de studiehandleiding voor details.
#
# Technische Instructies:
# - Git clone (als nog niet gedaan) het DEF repo en maak een branch voor werken aan deze opdracht. Nodig je groepsgenoot uit als collaborator. Hiervoor staat een manual op brightspace.
# - Dit notebook maakt gebruik van een aantal functies die in het bestand ```functions_electrostatics.py``` staan. Dit bestand moet in dezelfde map (folder) staan als dit notebook. Als je git clone doet, gaat dat automatisch goed, maar verplaats dit notebook dus niet naar een andere map, mail het niet naar een mede-student, etc. Als je niet weet wat een map (folder) en een bestand is, bekijk dan [deze tutorial](https://teachbooks.io/files-and-folders/EN/intro.html).
#
# Onderwijs Instructies:
# - Beantwoord de vragen die in dit notebook voor komen direct in dit notebook.
# - Als je iets moet printen op het scherm als antwoord op een vraag, doe dit op een gestructureerde manier met als dat relevant is de eenheid erbij, zoals je geleerd is bij het Inleidend Practicum.
# - Vermijd 'hardcoden' waar mogelijk.
# - Bij elke code cel staat aangegeven of jij hem moet aanpassen of alleen runnen. Lees bij cellen die je moet runnen, maar niet hoeft aan te passen, goed de code door om daarvan te leren en te gebruiken in de cellen die je wel moet aanpassen.
#
# Elektrostatica Opmerkingen:
# - In deze opdracht zullen jullie verschillende problemen bestuderen die as-symmetrie hebben. De opdrachten zullen daardoor, cilindrische coördinaten ($r$,$\phi$,$z$) gebruiken, waarbij $r$ de afstand tot de $z$ as is, $z$ de hoogte en $\phi$ de hoek met de $x$-as. Alle gebruikte problemen zullen ook in de $\phi$ richting symmetrisch zijn en die coördinaat zal dus niet uitmaken.
# - Voor elke sub-opdracht zal eerst het potentiaal bepaald worden en daarna zal het elektrische veld bepaald worden met de "finite difference" methode. Dit is een methode om de afgeleide te nemen van een dataset. Deze methode is geen onderdeel van de leerdoelen van het vak en komt later in je studie aan bod. We gebruiken "finite difference" hier als gereedschap en als voorbeeld van wat je later nog tegen gaat komen.

# %% [markdown]
# Vul de informatie in deze cel in:
#
# | Groep: 75     |  |
# | :-------------|:-------------|
# | Meike Ligtenberg | 6242545 |
# | Arjun Avhale|  |

# %%
# Run deze cel, pas deze niet aan
import numpy as np
import matplotlib.pyplot as plt
from functions_electrostatics import *
#from IPython import display
from IPython.display import Image, display


epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

"""============================================================================================
We first define the size of the domain of calculation and spatial discretization of the domain
"""

# Grid van het rekendomein; het veld wordt berekend in het (r,z)-vlak (asymmetrie):
width_domain = 5  # (m)
height_domain = width_domain  # maximum afstand van de schijf tot de grond, boven en beneden (m)
grid_step = 0.1  # grid stap grootte (m)

# %% [markdown]
# ### 1) Een puntlading in de oorsprong
#
# In deze opdracht gaan we in op een numerieke benadering van het potentiaal en elektrische veld rond een puntlading in de oorsprong.

# %%
# Run deze cel, pas de cel niet aan
charge_one_point = 1e-14  # lading van 1 punt (C)

r, z, B = initialize_plane_grid_for_pt_charge_at_origin(height_domain, width_domain, grid_step)
V = calculate_V_point_charge_at_origin(charge_one_point, r, z)

Er, Ez, normE = compute_E_pt_charge(V, B, grid_step)  # gebruik de centered finite-difference method
# met Er de r-component, Ez de z-component en normE de norm van het elektrische veld

r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

plot_results_pt_charge_at_origin(Ez, Er, normE, V, r, z, grid_step)

# %% [markdown]
# ##### Vraag 1a Het potentiaal rond een puntlading
#
# 1. Bepaal welke index correspondeert met $z = 0$ m.
# 2. Plot de log van het potentiaal tegen de log van de straal.
# 3. Fit de log van het potentiaal met de log van de straal.
# 4. Print het exponent op een nette manier.

# %%
###
###
z0_index = np.argmin(np.abs(z-0)) 
print("Index van z = 0:", z0_index)
    
V_z0 = V[z0_index, :]  # potentiaal op z = 0

mask = r > 0
r_nietnul = r[mask]
V_z0_nietnul = V_z0[mask]

log_r = np.log(r_nietnul)
log_V = np.log(V_z0_nietnul) 


plt.figure()
plt.plot(log_r, log_V, 'o', label='Data (log-log)')
plt.xlabel('log(r) (m)')
plt.ylabel('log(V) (V)')
plt.title('Log-log plot van potentiaal op z=0')
plt.legend()
plt.grid()
plt.show()

slope, intercept = np.polyfit(log_r, log_V, 1)
print(f"Slope (helling) van de log-log plot: {slope:.3f}")

fit_line = slope * log_r + intercept

plt.figure()
plt.plot(log_r, log_V, 'o', label='Data (log-log)')
plt.plot(log_r, fit_line, 'r-', label=f'Fit line (slope = {slope:.2f})')
plt.xlabel('log(r) (m)')
plt.ylabel('log(V) (V)')
plt.title('Log-log plot van potentiaal op z=0 met fit line')
plt.legend()
plt.grid()
plt.show()
###
###
# Out:
# Index van z = 0: 50
# Slope (helling) van de log-log plot: -1.000

# %% [markdown]
# ##### Vraag 1b Het elektrische veld rond een puntlading
# 1. Voer van vraag 1a 2 tot 4 uit voor het elektrische veld.

# %%
###
E_z0 = Ez[z0_index, :]  # elektrische veld op z = 0

r = np.array(r)
E_z0 = np.array(E_z0)

min_len = min(len(r), len(E_z0)) 
r = r[:min_len]
E_z0 = E_z0[:min_len]

mask = r > 0
r_nietnul = r[mask]
E_z0_nietnul = E_z0[mask]

log_r = np.log(r_nietnul)
log_E = np.log(np.abs(E_z0_nietnul))  # abs to avoid log(0)

plt.figure()
plt.plot(log_r, log_E, 'o', label='Data (log-log)')
plt.xlabel('log(r) (m)')
plt.ylabel('log(E) (V/m)')
plt.title('Log-log plot van elektrisch veld op z=0')
plt.legend()
plt.grid()
plt.show()

slope, intercept = np.polyfit(log_r, log_E, 1)
print(f"Slope (helling) van de log-log plot: {slope:.3f}") 

fit_line = slope * log_r + intercept

plt.figure()
plt.plot(log_r, log_E, 'o', label='Data (log-log)')
plt.plot(log_r, fit_line, 'r-', label=f'Fit line (slope = {slope:.2f})') 
plt.xlabel('log(r) (m)')
plt.ylabel('log(E) (V/m)')
plt.title('Log-log plot van elektrisch veld op z=0 met fit line')
plt.legend()
plt.grid()
plt.show()

###
# Out:
# Slope (helling) van de log-log plot: -2.565

# %% [markdown]
# ### 2) Een uniform geladen schijf bestaande uit puntladingen
#
# In de code hieronder wordt een geladen schijf gemaakt via het superpositie principe. Dit wordt gedaan door een rooster van punten in de ruimte te creëren, alle punten die voldoen aan $z = 0$ m en $r < R$ krijgen een lading charge_one_point en vanuit hier wordt het potentiaal bepaald. Hier is de $z$-as de as van de schijf en de r as de afstand tot de $z$-as.

# %%
# In vraag 2.1 wordt naar deze cel verwezen.
disk_radius = 3  # (m)
grid_step = 0.1  # (m)
z_coord_DISK = 0  # (m) positie van de schijf op de z-as
inter_charge_distance = grid_step  # (m) afstand tussen punt ladingen

# %%
# Kies uit deze cel een van de variabelen en verander die in de cel hierboven pas deze cel zelf niet aan.
r, z, B = initialize_plane_grid_for_uniformly_charged_disk(height_domain, width_domain, grid_step)

idx_z_zero = np.where(abs(z) < 1e-10)[0]
z_coord_DISK = 0  # (m) positie van de schijf op de z-as
inter_charge_distance = grid_step  # (m) afstand tussen punt ladingen

V_disk, number_point_charges_on_disk = calculate_V_disk_at_origin_uniform_surface_charge_density(z_coord_DISK, charge_one_point, disk_radius, inter_charge_distance, r, z)
Er, Ez, normE = compute_E_disk(V_disk, B, grid_step)  # gebruik de centered finite-difference method

r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

plot_results_disk(Ez, Er, normE, V_disk, r, z, grid_step, disk_radius, z_coord_DISK, z_coord_DISK)

# %% [markdown]
# #### Vraag 2a
#
# In deze vraag gaan jullie achterhalen wat de variabelen die aan het begin van opgave 2 worden geïnitialiseerd betekenen voor de nauwkeurigheid en snelheid van de code.
# Pas voor deze vraag de code die net onder het kopje vraag 2 staat aan. Run dan die cel en de cel daaronder opnieuw om het resultaat van je aanpassing te zien.
# 1. Wat betekent de disk radius variabele die in de bovenste cel geïnitialiseerd wordt, wat gebeurt er als disk radius naar 0 gaat?
# 2. Wat betekent gridstep en wat voor impact heeft deze variabele op de simulatie?
# 3. Pak uit de tweede code cel in opdracht 2 een andere variabelen en onderzoek wat deze variabele doet en wat voor impact die heeft op de simulatie.

# %% [markdown]
# ##### Antwoorden 2a
#
# 1. De disk radius variabele is de straal van de schijf. Het aantal puntladingen in de schijf neemt af bij een kleinere straal. Wanneer de straal van de schijf naar 0 gaat, wordt de schijf heel klein, waardoor de schijf gaat lijken op een puntlading. Het elektrisch veld gaat er dan dus ook uitzien als die van een puntlading.
#
# 2. de gridstep is de afstand tussen de puntladingen en de stapgrootte van het rooster in de r en z richting. Een kleinere gridstep zorgt voor meer puntladingen op de schijf.
#
# 3. z_coord_DISK: deze variabele geeft de positie van de schijf aan op de z-as. Als je deze variabele gelijk stelt aan 1, komt de schijf op hoogte z = 1 te liggen.

# %% [markdown]
# #### Vraag 2b Oppervlakte lading
#
# Pas de cel die je in vraag 2a hebt aangepast weer aan naar de originele waardes. Run hierna alle code cellen na vraag 2 weer opnieuw.
# Het aantal punten dat gebruikt wordt om de schijf te creëren is number_point_charges_on_disk en de lading van een punt is charge_one_point in Coulomb.
# 1. Bereken en print de ladingsdichtheid $\sigma$ met een correcte eenheid.

# %%
###
sigma = number_point_charges_on_disk * charge_one_point / (np.pi * disk_radius**2)  # oppervlakte ladingsdichtheid (C/m^2)
print(f"Oppervlakte ladingsdichtheid (sigma): {sigma:.3e} C/m^2") 
###
# Out:
# Oppervlakte ladingsdichtheid (sigma): 9.949e-13 C/m^2

# %% [markdown]
# ##### Vraag 2c
#
# 1. Plot het elektrische potentiaal langs de $r$ as ($z = 0$ m).
# 2. Plot het potentiaal op de rand van de schijf in hetzelfde figuur $V = \sigma R/(\pi \epsilon_0)$
# (bekijk probleem 2.51 in het Griffiths' boek)
# 3. Plot het potentiaal in het centrum van de schijf in hetzelfde figuur $V = \sigma R/(2 \epsilon_0)$

# %%
# Vul deze code aan zodat deze vraag 2.3 beantwoord.
idx_z_zero = np.argmin(np.abs(z-0))  # index van z = 0
idx_r_zero = np.argmin(np.abs(r-0))  # index van r = 0
idx_r_R = np.argmin(np.abs(r-disk_radius))  # index van r = R

V = V_disk[idx_z_zero, :]  # potentiaal op z = 0

epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)
V_0 = sigma * disk_radius / (2 * epsilon0)  # theoretisch potentiaal op r = 0 m, zie formule in vraag 2.3
V_R = sigma * disk_radius / (np.pi * epsilon0)  # theoretisch potentiaal op r = R m, zie formule in vraag 2.3
r_R = r[idx_r_R]  # straal van de schijf

plt.title(f"Elektrisch potentiaal van een uniform geladen schijf") 
plt.plot(r, V, "o-", label="numeriek potentiaal")
plt.plot(0, V_0, "c.", label="theoretisch potentiaal $r$=0 m")
plt.plot(r_R, V_R, "c.", label="theoretisch potentiaal $r$=$R$ m")
plt.legend()
plt.xlabel("r (m)")
plt.ylabel("V (V)")
# Out:
# Text(0, 0.5, 'V (V)')

# %% [markdown]
# #### Vraag 2d
#
# Het theoretische potentiaal op de as van een hele grote schijf ($R>>z$) is:
# $V(z, r=0) = \frac{\sigma}{2\epsilon_0} \big( R - |z|\big)$
# zie probleem 2.26 in het Griffiths boek.
# 1. Plot het numeriek berekend elektrische potentiaal op de $z$-as ($r=0$).
# 2. Plot het theoretische component van het potentiaal op de as van een schijf met ladingsdichtheid $\sigma$.
# 3. Sla deze plot op.

# %%
###
idx_r_zero = np.argmin(np.abs(r-0))  # index van r = 0
V_z_as = V_disk[:, idx_r_zero]  # potentiaal op r = 0 m

V_z_as_theoretisch = (sigma / (2 * epsilon0)) * (disk_radius - np.abs(z))  # theoretisch potentiaal op r = 0 m, zie formule in vraag 2.3

plt.figure()
plt.plot(z, V_z_as, 'o-', label='Numeriek potentiaal op r=0 m')
plt.plot(z, V_z_as_theoretisch, 'r-', label='Theoretisch potentiaal op r=0 m')
plt.xlabel('z (m)')
plt.ylabel('V (V)')
plt.title('Elektrisch potentiaal op de z-as (r=0 m)')
plt.legend()
plt.grid()
plt.savefig("vraag_2d_plot.png") 
plt.show() 
###

# %% [markdown]
# #### Vraag 2e
#
# Het theoretische elektrische veld van een oneindig geladen oppervlakte is $|E| = \sigma/(2 \epsilon_0)$ (zie Example 2.5 in het Griffith boek).
# 1. Plot het z-component van het numeriek berekende elektrische veld op de as van de schijf ($r=0$).
# 2. Plot het theoretische elektrische veld voor een oneindig geladen oppervlak.
# 3. Sla deze plot ook op.

# %%
###
E_z_as = Ez[:, idx_r_zero]  # elektrisch veld op r = 0 m
min_len = min(len(z), len(E_z_as)) 
z_aangepast = z[:min_len]
E_z_as = E_z_as[:min_len]

E_theoretisch = np.full_like(z_aangepast, sigma / (2 * epsilon0))  # theoretisch elektrisch veld op r = 0 m, zie formule in vraag 2.3


plt.figure()
plt.plot(z_aangepast, E_z_as, 'o-', label='Numeriek elektrisch veld op r=0 m')
plt.plot(z_aangepast, E_theoretisch, 'r-', label='Theoretisch elektrisch veld (oneindig geladen oppervlak)') 
plt.xlabel('z (m)')
plt.ylabel('E (V/m)')
plt.title('Elektrisch veld op de z-as') 
plt.legend()
plt.grid()
plt.savefig("vraag_2e_plot.png")
plt.show()
###

# %% [markdown]
# #### Vraag 2f
# 1. Waar benadert het elektrische veld van een uniform geladen schijf dat van een oneindig geladen plaat?
# 2. Beschrijf en verklaar de verschillen die je opvallen in de plot die je bij vraag 2e hebt gemaakt.

# %% [markdown]
# ##### Antwoorden 2f
# 1. Het elektrische veld van een uniform geladen schijf benadert het elektrische veld van een oneindig geladen plaat als z naar 0 meter toe gaat. Dicht bij de schijf is het elektrisch veld dus bijna constant.
# 2. In de plot bij vraag 2e zien we dat het elektrisch veld afneemt als |z| toe neemt. Als |z| >> R, gaat het elektrisch veld zich gedragen als dat van een puntlading, waardoor het elektrisch veld kwadratisch afneemt met de afstand tot de schijf.

# %% [markdown]
# #### Vraag 2g
#
# 1. Pas helemaal bovenaan in vraag 2 de straal van de schijf aan.
# 2. Voer dan vragen 2d en 2e opnieuw uit.
# 3. Voeg de opgeslagen figuren hieronder toe.
# 4. Beschrijf de verschillen tussen de twee verschillende stralen.

# %%
### 
# vraag 2d
disk_radius_klein = 1.5

r, z, B = initialize_plane_grid_for_uniformly_charged_disk(height_domain, width_domain, grid_step)

idx_z_zero = np.where(abs(z) < 1e-10)[0]
z_coord_DISK = 0  # (m) positie van de schijf op de z-as
inter_charge_distance = grid_step  # (m) afstand tussen punt ladingen

V_disk_klein, number_point_charges_on_disk_klein = calculate_V_disk_at_origin_uniform_surface_charge_density(z_coord_DISK, charge_one_point, disk_radius_klein, inter_charge_distance, r, z)
Er_klein, Ez_klein, normE_klein = compute_E_disk(V_disk_klein, B, grid_step)  # gebruik de centered finite-difference method

r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

idx_r_zero = np.argmin(np.abs(r-0))  # index van r = 0
V_z_as_klein = V_disk_klein[:, idx_r_zero]  # potentiaal op r = 0 m

V_z_as_theoretisch_klein = (sigma / (2 * epsilon0)) * (disk_radius_klein - np.abs(z))  # theoretisch potentiaal op r = 0 m, zie formule in vraag 2.3

plt.figure()
plt.plot(z, V_z_as_klein, 'o-', label='Numeriek potentiaal op r=0 m')
plt.plot(z, V_z_as_theoretisch_klein, 'r-', label='Theoretisch potentiaal op r=0 m')
plt.xlabel('z (m)')
plt.ylabel('V (V)')
plt.title('Elektrisch potentiaal op de z-as (r=0 m) met kleinere straal van de schijf')
plt.legend()
plt.grid()
# plt.savefig("vraag_2d_g_plot.png") 
plt.show() 

# vraag 2e
E_z_as_klein = Ez_klein[:, idx_r_zero]  # elektrisch veld op r = 0 m
min_len = min(len(z), len(E_z_as_klein)) 
z_aangepast = z[:min_len]
E_z_as_klein = E_z_as_klein[:min_len]

E_theoretisch_klein = np.full_like(z_aangepast, sigma / (2 * epsilon0))  # theoretisch elektrisch veld op r = 0 m, zie formule in vraag 2.3


plt.figure()
plt.plot(z_aangepast, E_z_as_klein, 'o-', label='Numeriek elektrisch veld op r=0 m')
plt.plot(z_aangepast, E_theoretisch_klein, 'r-', label='Theoretisch elektrisch veld (oneindig geladen oppervlak)') 
plt.xlabel('z (m)')
plt.ylabel('E (V/m)')
plt.title('Elektrisch veld op de z-as met kleinere straal van de schijf')
plt.legend()
plt.grid()
# plt.savefig("vraag_2e_g_plot.png")
plt.show()
###
display(Image("vraag_2d_plot.png"))
display(Image("vraag_2e_plot.png"))

# %% [markdown]
# ##### Antwoorden 2g
#
# We hebben de straal gehalveerd (van 3 m naar 1,5 m), hierdoor is het elektrisch potentiaal in het midden van de schijf bij z = 0 gehalveerd. Dit komt ook overeen met de formule $V(z, r=0) = \frac{\sigma}{2\epsilon_0} \big( R - |z|\big)$ voor het potentiaal op de as van een hele grote schijf ($R>>z$), want daar is de potentiaal lineair afhankelijk van de straal.
# Ook buigt de blauwe lijn sneller af van de rode lijn bij een kleinere straal, bij een kleinere straal gaat het potentiaal namelijk al bij een kleinere afstand tot de schijf lijken op die van een puntlading, waardoor het potentiaal afneemt met 1/z in plaats van een lineaire afname met z.
#
# Daarnaast zien we in de grafiek voor het elektrisch veld dat de blauwe lijn veel sneller daalt zodra de afstand tot de schijf groter wordt. Doordat de schijf kleiner is, komt een kleiner gebied van de schijf overeen met een oneindig geladen schijf. Bij de grotere straal komt het elektrisch veld langer overeen met die van een oneindig geladen schijf.

# %% [markdown]
# #### Vraag 2h
# Het elektrische veld een afstand $z$ boven het midden van een uniform geladen schijf met een straal $R$ en oppervlakte lading $\sigma$ wordt gegeven door:
# $$ \mathbf{E} = \frac{\sigma}{2\epsilon_0} \bigg[ 1- \frac{z}{\sqrt{R^2 + z^2}}\bigg] \hat{\mathbf{z}}$$
# Zie probleem 2.6 in het boek van Griffith.
#
# 1. Wat moet de hoogte $z$ zijn boven de schijf zodat het elektrische veld door de schijf 10% is in vergelijking met dat van een oneindig geladen plaat?
#
# Voeg hieronder je analytische uitwerking toe.

# %% [markdown]
# ##### Antwoord 2h
#
# ![Vraag 2h](vraag_2h.jpeg)
# De hoogte moet dus ongeveer 2,06 keer de straal worden.

# %% [markdown]
# ### 3) Een geladen schijf op een constant potentiaal
#
# We zullen nu het verschil bestuderen tussen een uniform geladen schijf en een geleidende schijf die op een bepaald potentiaal gehouden wordt.
# De code hieronder lost numeriek de laplace vergelijking op voor een geleidende schijf op een constant potentiaal. Hieruit volgt het potentiaal in de ruimte.

# %%
# Run deze cel pas deze niet aan.

V0 = 0  # electric potential at boundary of domain (V)

# Één schijf
z_pos_disk1 = 0  # z-coördinaat van de eerste geleidende schijf (m)
z_pos_disk2 = z_pos_disk1  # z-coördinaat van de tweede geleidende schijf (m)
V1 = 10  # elektrische potentiaal van de eerste geleidende schijf (V)

r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain, disk_radius, height_domain, grid_step, z_pos_disk1, z_pos_disk2, V0, V1, V1)

"""--------------------------------------------------------------------
Veldberekening voor een geleidende schijf
"""
solve_Laplace_equation(V, B, r_repmat, grid_step, idx_z1, idx_z2, idx_R, V1, V1, 1e-3)
Er, Ez, normE = compute_E_disk(V,B,grid_step)
r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

""""---------------------------------------------------------
Plot het berekende veld
"""
plot_results_disk(Ez, Er, normE, V, r, z, grid_step, disk_radius, z_pos_disk1, z_pos_disk2)

# %% [markdown]
# #### Vraag 3a: De simulatie van het elektrische veld van een geleidende schijf op constant potentiaal
#
# 1. Plot de elektrische veld sterkte op de as van de schijf.
# 2. Print de norm van het elektrische veld op de as heel dicht bij het midden van de schijf, zorg hier voor een nette opmaak.

# %%
###
idx_r_zero = np.argmin(np.abs(r-0))  # index van r = 0
Ez_z_as = Ez[:, idx_r_zero]  # elektrisch veld op r = 0 m
min_len = min(len(z), len(Ez_z_as))
z_aangepast_3a = z[:min_len]
Ez_z_as = Ez_z_as[:min_len]

plt.figure()
plt.plot(z_aangepast_3a, Ez_z_as, 'o-', label=' elektrisch veld op r=0 m')
plt.xlabel('z (m)')
plt.ylabel('Ez (V/m)')
plt.title('Elektrisch veld op de z-as (r=0 m) voor geleidende schijf op constant potentiaal')
plt.legend()
plt.grid()
plt.show() 

E_norm_z_as = normE[:, idx_r_zero]  # norm van het elektrische veld op r = 0 m
idx_z_vlakbij_nul = np.argmin(np.abs(z-0.1))  # index van z net boven de schijf
E_norm_z_vlakbij_nul = E_norm_z_as[idx_z_vlakbij_nul]  # norm van het elektrische veld net boven de schijf
print(f"Norm van het elektrische veld op de as heel dicht bij midden van schijf: {E_norm_z_vlakbij_nul:.3e} V/m")
###
# Out:
# Norm van het elektrische veld op de as heel dicht bij midden van schijf: 4.182e+00 V/m

# %% [markdown]
# #### Vraag 3b: De oppervlakte lading in het midden van een geleidende schijf op constant potentiaal
#
# 1. Met welke formule kan je de oppervlaktelading benaderen in het midden van de schijf($r=0$, $z=0$)?
# 2. Print netjes de benadering van de oppervlakte lading in het midden van de schijf.

# %% [markdown]
# ##### Antwoord 3b
#
# sigma_midden = epsilon0 * E_norm_z_vlakbij_nul

# %%
#### Print met deze cel met een nette opmaak je antwoord op vraag 3b 2.
sigma_midden = epsilon0 * E_norm_z_vlakbij_nul  # oppervlakte ladingsdichtheid in het midden van de schijf (C/m^2)
print(f"Oppervlakte ladingsdichtheid in het midden van de schijf: {sigma_midden:.3e} C/m^2")
# Out:
# Oppervlakte ladingsdichtheid in het midden van de schijf: 3.703e-11 C/m^2

# %% [markdown]
# #### Vraag 3c: De oppervlaktelading van een geleidende schijf op constant potentiaal
#
# De oppervlakte lading $\sigma(r)$ van een geleidende schijf met straal $R$ is niet uniform verdeeld over de schijf, maar wordt gegeven door (Problems 2.58 and 2.63 Griffiths 5th edition):
# $$\sigma(r) = \frac{Q}{2 \pi R \sqrt{R^2 - r^2}}$$
#
# 1. Bereken de totale lading op de schijf met behulp van vraag 3a en 3b.
# 2. Vergelijk de oppervlakte lading in het centrum van de geleidende schijf met dat van een uniform geladen schijf met dezelfde totale lading.
# 3. Plot de oppervlakte lading van de geleidende schijf met de berekende lading $Q$, tussen $r = 0$ en $R$.
# 4. Plot in hetzelfde figuur de oppervlaktelading van een uniform geladen schijf met dezelfde lading $Q$.

# %%
###
dr = r[1] - r[0]  # afstand tussen gridpunten in de r-dimensie
r_schijf = r[idx_r_zero : idx_R+1]
sigma_r = epsilon0 * normE[idx_z_vlakbij_nul, idx_r_zero : idx_R+1]  # oppervlakte ladingsdichtheid als functie van r (C/m^2)
Q_totaal = np.sum(sigma_r * 2 * np.pi * r_schijf * dr)  # totale lading op de schijf (C)

sigma_uniform = Q_totaal / (np.pi * disk_radius**2)  # oppervlakte ladingsdichtheid van uniform geladen schijf (C/m^2)

plt.figure()
plt.plot(r_schijf, sigma_r, 'o-', label='Oppervlakte ladingsdichtheid geleidende schijf')
plt.axhline(sigma_uniform, color='r', linestyle='--', label='Oppervlakte ladingsdichtheid uniform geladen schijf')
plt.xlabel('r (m)')
plt.ylabel('Oppervlakte ladingsdichtheid (C/m^2)')
plt.title('Oppervlakte ladingsdichtheid als functie van r')
plt.legend()
plt.grid()
plt.show()
###

# %% [markdown]
# #### Vraag 3d: Het edge effect
#
# 1. Bepaal het maximum elektrische veld door de geleidende schijf in de simulatie.
# 2. Bepaal waar in de ruimte dit maximum zich bevindt.
# 3. Hoeveel hoger is dit maximum dan het elektrische veld in het midden van de schijf?
# 4. Print met een nette opmaak de waardes die je hier hebt berekend.
# 5. Leg uit wat de oorzaak van dit lokaal hoge elektrische veld is?

# %%
# Deze cel kan je gebruiken om van vraag 3c 1 tot en met 4 te beantwoorden.
max_E = np.max(normE)  # maximale waarde van de norm van het elektrische veld
print(f"Maximale waarde van het elektrische veld: {max_E:.3e} V/m")

idx_max = np.unravel_index(np.argmax(normE, axis=None), normE.shape)
z_max_loc = z[idx_max[0]]
r_max_loc = r[idx_max[1]]

print(f"Locatie van maximale veldsterkte: z = {z_max_loc:.3f} m, r = {r_max_loc:.3f} m")

verschil_E = max_E - E_norm_z_vlakbij_nul
print(f"Verschil tussen maximale veldsterkte en veldsterkte vlakbij midden van de schijf: {verschil_E:.3e} V/m")
# Out:
# Maximale waarde van het elektrische veld: 1.175e+01 V/m
# Locatie van maximale veldsterkte: z = -0.000 m, r = 2.900 m
# Verschil tussen maximale veldsterkte en veldsterkte vlakbij midden van de schijf: 7.571e+00 V/m

# %% [markdown]
# ##### Antwoord 3d.5
# Het hoge elektrische veld bevindt zich op de rand van de schijf. Het elektrisch veld binnen de schijf moet namelijk nul zijn en het potentiaal van de schijf moet overal gelijk zijn. De ladingen stoten elkaar af en hopen zich op aan de rand. Hierdoor neemt de oppervlakte ladingsdichtheid aan de rand dus toe, waardoor het elektrisch veld hier ook sterker is.

# %% [markdown]
# ### 4) Twee geleidende platen op potentiaal $V_1$ and $-V_1$
#
# In de cel hieronder wordt weer op dezelfde manier als in opdracht 3 de laplace vergelijking van deze situatie opgelost.

# %%
# Run deze cel en pas de cel aan in vraag 4f.
# Voor twee schijven
spacing_between_disks = 0.5  # (m)
z_pos_disk1 = spacing_between_disks/2  # z-coördinaat van de eerste geleidende schijf (m)
z_pos_disk2 = -spacing_between_disks/2  # z-coördinaat van de tweede geleidende schijf (m)
V1 = 10  # elektrische potentiaal van de eerste geleidende schijf (V)
V2 = -10  # elektrische potentiaal van de tweede geleidende schijf (V)

r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain, disk_radius, height_domain, grid_step, z_pos_disk1, z_pos_disk2, V0, V1, V2)

"""--------------------------------------------------------------------
Veldberekening voor de twee geleidende schijven
"""
solve_Laplace_equation(V, B, r_repmat, grid_step, idx_z1, idx_z2, idx_R, V1, V2, 1e-3)
Er, Ez, normE = compute_E_disk(V, B, grid_step)
r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

""""---------------------------------------------------------
Plot het berekende veld
"""
plot_results_disk(Ez, Er, normE, V, r, z, grid_step, disk_radius, z_pos_disk1, z_pos_disk2)

# %% [markdown]
# #### Vraag 4a: Het $z$-component van het numeriek berekende elektrische veld van twee geleidende platen
#
# 1. Plot het $z$-component van het numeriek berekende elektrische veld op de as van de schijven.

# %%
###
#Note: Variables from now on may be changed in terms of language to english as I prefer to work in english, metadata will make it clear though what the variable means. 

idx_r_zero = np.argmin(np.abs(r-0))  # index where r=0
Ez_axis = Ez[:, idx_r_zero] #extracting the z-axis field: all z-rows at that radial index
min_len = min(len(z_for_E), len(Ez_axis)) # ensures same length for plotting (because I kept getting shape error otherwise)
z_axis = z_for_E[:min_len] #adjusting z-axis length to match Ez_axis length
Ez_axis = Ez_axis[:min_len] #adjusting Ez_axis length to match z_axis length

#plotting this
plt.figure()
plt.plot(z_axis, Ez_axis, '-o')
plt.xlabel('z (m)')
plt.ylabel('Ez (V/m)')
plt.title('z component of the electric field on the axis of the disks')
plt.grid()
plt.show()
###

# %% [markdown]
# #### Vraag 4b: Verschillen tussen verschillende configuraties
#
# 1. Gegeven het potentiaal tussen twee geleidende platen, wat is het theoretische elektrische veld in elke regio? Laat dit zien met een afleiding en een schets die de verschillende regio's aangeeft.
# 2. Beschrijf het numeriek berekende elektrische veld op de as van de schijven, komt dit overeen met het theoretische elektrische veld?
# 3. Vergelijk het numeriek berekende elektrische veld tussen de twee schijven ($r=0$ and $z=0$) met dat van een enkele geleidende schijf op hetzelfde potentiaal(vraag 3a), welk voordeel heeft deze configuratie?

# %% [markdown]
# ##### Antwoorden 4b
# ![Vraag 4b_1](foto_vraag_4d.jpeg)
# 2. Using the derived formula in 4b, at a separation of 2m the electric field = 10 V/m, this is also seen an verified by the graph in 4a. Therefore yes, the theoretical and physical calculations match.
# 3. Single disk (3a): approximately 4.18V/m around z=0 and 2 and 2 disks (4a)L 10 V/mat around z=0. Advantage of 2 disk configuration: Field is approximately constant between the plates, unlike the single disk where field decreases with distance

# %% [markdown]
# #### Vraag 4c: De capaciteit tussen twee geleidende platen
#
# 1. Bepaal de verwachte oppervlakte lading op de binnenzijde van een van de schijven.
# 2. Bepaal de verwachte totale lading op beide schijven.
# 3. Bepaal de capaciteit van deze situatie.
# 4. Print alle bepaalde waardes op een nette en overzichtelijke manier.

# %%
###
d = spacing_between_disks # distance between 2 disks
A = np.pi*disk_radius**2 # area of one disk

sigma_inside = 2*epsilon0*V1 / d # surface charge density in the middle of the disk (C/m^2)

Q_pos = sigma_inside*A #charge on one disk (C),
Q_neg = -Q_pos # charge on the other side of th disk (C)

C = epsilon0*A/d #capacitance of the system (F)

print("Distance between disk (d):", d, "m")
print(f"Area of one disk (A): {A:.3e} m^2")
print(f"Surface charge density in the middle of the disk (sigma_inside): {sigma_inside:.3e} C/m^2")
print(f"Charge on positive disk: {Q_pos:.3e} C")
print(f"Charge on negative disk: {Q_neg:.3e} C")
print(f"Magnitude of total charge on both disks: {Q_pos + abs(Q_neg):.3e} C")
print(f"Capacitance of the system: {C:.3e} F")
###
# Out:
# Distance between disk (d): 0.5 m
# Area of one disk (A): 2.827e+01 m^2
# Surface charge density in the middle of the disk (sigma_inside): 3.542e-10 C/m^2
# Charge on positive disk: 1.001e-08 C
# Charge on negative disk: -1.001e-08 C
# Magnitude of total charge on both disks: 2.003e-08 C
# Capacitance of the system: 5.007e-10 F

# %% [markdown]
# #### Vraag 4d: Theoretische oppervlakte lading
#
# 1. Is de oppervlaktelading aan de buitenkant van de schijven gelijk aan nul, beargumenteer waarom wel of niet.
# 2. Wat is het elektrische veld nabij het oppervlak van een geleider?

# %% [markdown]
# ##### Antwoorden 4d
#
# 1. Yes the surface charge on the outside can be 0, or at the very least negligible. This is assuming an idealised theoretical model like we have taken for calculations. The reason for this statement is that both plates have opposite charges, and these opposite charges create opposing electric fields that can essentially cancel each other out beyond the confined region.
#
# Following gauss law (formula obtained during EM - Lecture 3 - Elektrische potentiaal): $$\sigma = \epsilon_0 E_{\perp}$$
#
# We determined the electric field to be 0 therefore, the surface charge too is 0
#
# 2. Essentially used in part 1, the electric field past the surface of a conductor is given by:
#  $$\sigma = \epsilon_0 E_{\perp}$$
#
# Therefore:
# $$E_{\perp} = \frac{\sigma}{\epsilon_0}$$
#
# $$(E_\perp) = \text{component of the electric field perpendicular to the surface (V/m)}$$
# $$(\sigma) = \text{surface charge density at that point} (C/m^2)$$
# $$(\varepsilon_0) = \text{vacuum permittivity (F/m)}$$

# %% [markdown]
# #### Vraag 4e: Numeriek berekende ladingsdichtheid
#
# 1. Welke waarde heeft het $z$-component van het elektrische veld, op de as van de schijf net onder de onderste schijf.
# 2. Wat is volgens de formule uit vraag 4d 2 de ladingsdichtheid aan de onderkant van de onderste geleidende plaat.
# 3. Welke waarde heeft het $z$-component van het elektrische veld, op de as van de schijf net boven de onderste schijf.
# 4. Wat is volgens de formule uit vraag 4d 2 de ladingsdichtheid aan de bovenkant van de onderste geleidende plaat.
# 5. Print de bepaalde waardes op een nette en overzichtelijke manier.

# %%
###
#The value of the z component of the electric field on the axis of the disk under the the first disk
idx_r0 = idx_r_zero # index were r=0 (so that we find it on the axis of the disk)
z_bottom = z_pos_disk2 # z-coordinate of the bottom disk (location of where we want to determine electric field)

#Finding grid points just above and below the disk_radius
idx_below = np.argmin(np.abs(z-(z_bottom - grid_step/2))) # gives the index of the grid point just below the disk radius, i choose to div by 2 to get it closer
idx_above = np.argmin(np.abs(z-(z_bottom + grid_step/2))) # same as idx_below but not for a point just above the disk

#z-comp of the field at the determined points 
Ez_below = Ez[idx_below, idx_r0]
Ez_above = Ez[idx_above, idx_r0]

#surface charge densities via formula from question 4d 2
sigma_below = epsilon0*Ez_below 
sigma_above = epsilon0*Ez_above

print(f"z component of the electric field just below the bottom disk: {Ez_below} V/m")
print(f"z component of the electric field just above the bottom disk: {Ez_above} V/m")
print(f"Surface charge density just below the bottom disk: {sigma_below:.6e} C/m^2") # i have not rounded to 3sf here because the difference in values is too small to see (above and below)
print(f"Surface charge density just above the bottom disk: {sigma_above:.6e} C/m^2") 

###
# Out:
# z component of the electric field just below the bottom disk: -17.796546862333436 V/m
# z component of the electric field just above the bottom disk: -39.9999999999667 V/m
# Surface charge density just below the bottom disk: -1.575706e-10 C/m^2
# Surface charge density just above the bottom disk: -3.541600e-10 C/m^2

# %% [markdown]
# #### Vraag 4f: Conclusies over de ladingsdichtheid op de twee schijven
#
# 1. Wat kan je uit vraag 4d en e concluderen over de daadwerkelijke lading op een schijf in tegenstelling tot de berekende lading in vraag 4c?
# 2. Wat is de invloed hiervan op de capaciteit berekend in vraag 4c?
# 3. Run de cel net onder het kopje vraag 4 opnieuw, maar dan met een kleinere afstand tussen de schijven, wat verandert er?

# %% [markdown]
# ##### Antwoorden 4f
#
# 1. The charge distribution calculated in 4d and 4e shows that most of the charge resides on the disk itself however it is not uniform as calculated in 4c. In 4e we see how the charge varies (ever so slightly)
# 2. Because the charge distribution is not uniform as proven by 4e, the actual capacitance should be slighlty larger, as the field lines spread out over a larger area hence a larger capacitance (using the formula for C).
# 3. Having reduced the distance (d), the charge density and electric field increased.

# %% [markdown]
# ### 5) Voorbereidende opdracht voor de fysieke DEF ontwerpopdracht
#
# In deze vraag zullen we ingaan op benodigde voorkennis voor de fysieke ontwerpopdracht "Maak een sensor met condensatoren". De formules die je in deze opdracht opstelt, heb je nodig gedurende de fysieke ontwerpopdracht.
#
# In deze vraag zullen we kijken naar de ideale vlakke plaat condensator. Als de afstand tussen de platen veel kleiner is dan de grootte van de platen dan wordt de aanname gemaakt dat het veld tussen de platen constant is. Deze aanname zal niet helemaal overeenkomen met de werkelijkheid, zoals je in deze opdracht en de fysieke DEF ontwerpopdracht achter zal komen.

# %% [markdown]
# #### Vraag 5a: Functies voor de capaciteit van enkele opdrachten
#
# 1. Vind de formule voor de capaciteit van een vlakke plaat condensator en een cilinder condensator, onder de aanname dat de afstand tussen de platen veel kleiner is dan het oppervlakte van de condensator (vlakke plaat aanname).
# 2. Schrijf een python functie die de relevante parameters als input neemt en de capaciteit van een vlakke plaat condensator als output heeft.
# 3. Vind de formule voor de capaciteit van een cilinder condensator onder de aanname dat de afstand tussen de binnen en buiten wand klein is.
# 4. Schrijf een python functie die de relevante parameters als input neemt en de capaciteit van een cilinder condensator als output heeft.

# %%
def vlakkeplaat(A, D):
    C_v = epsilon0*A/D #A = area of plate in m^2, D = distance between plates
    return C_v

def cilinder(a, b, L):
    C_c = 2*np.pi*epsilon0*L/np.log(b/a) #a = inner radius, b = outer radius, L = length of cylinder
    return  C_c

# %% [markdown]
# #### Vraag 5b: Capaciteit van enkele simpele condensatoren
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
# Hieronder staan een aantal condensatoren waarvoor jullie de capaciteit gaan berekenen. Print de capaciteit van elke condensator op een nette en overzichtelijke manier.
# 1. Bereken de capaciteit van een condensator gemaakt van twee vierkante plaatjes van 10 bij 10 cm met een plaatafstand van 1 mm en lucht als medium?
# 2. Bereken de capaciteit van een cilinder condensator met een binnendiameter van 9 mm en een buitendiameter van 10 mm met een lengte van 10 cm en lucht als medium?
# 3. Bereken de capaciteit van de condensatoren als de afstand tussen de platen verdubbeld
# 4. Bereken de capaciteit van de condensatoren uit 1 en 2 hierboven beschreven als ze gevuld zijn met water.
# 5. Bereken de capaciteit van de condensatoren uit 1 en 2 hierboven als de holte gevuld is met PVC.

# %%
###
A_p = 0.1*0.1 # area of plate in m^2
D_p = 0.001 # distance between plates in m

C_plate = vlakkeplaat(A_p,D_p)

I_r = 0.009/2 # inner radius of cylinder in m
O_r = 0.01/2 # outer radius of cylinder in m
L_c = 0.1 # length of cylinder in ma

C_cyl = cilinder(I_r,O_r,L_c)

#Doubling the gap

D_2 = 2*D_p
C_plate_2 = vlakkeplaat(A_p,D_2)

#Filling with water
epsilon_r_water = 80 # relative permittivity

C_plate_water = C_plate * epsilon_r_water 
C_cyl_water = C_cyl * epsilon_r_water

#Filling with pvc

epsilon_r_pvc = 4 # relative permittivity of pvc 

C_plate_pvc = C_plate * epsilon_r_pvc
C_cyl_pvc = C_cyl * epsilon_r_pvc

print(f"1. Plate capacitor (air): {C_plate:.3e} F")
print(f"2. Cylinder capacitor (air): {C_cyl:.3e} F")
print(f"3. Plate capacitor (double gap): {C_plate_2:.3e} F")
print(f"4. Plate capacitor (water): {C_plate_water:.3e} F")
print(f"4. Cylinder capacitor (water): {C_cyl_water:.3e} F")
print(f"5. Plate capacitor (PVC): {C_plate_pvc:.3e} F")
print(f"6. Cylinder capacitor (PVC): {C_cyl_pvc:.3e} F")

###
# Out:
# 1. Plate capacitor (air): 8.854e-11 F
# 2. Cylinder capacitor (air): 5.280e-11 F
# 3. Plate capacitor (double gap): 4.427e-11 F
# 4. Plate capacitor (water): 7.083e-09 F
# 4. Cylinder capacitor (water): 4.224e-09 F
# 5. Plate capacitor (PVC): 3.542e-10 F
# 6. Cylinder capacitor (PVC): 2.112e-10 F

# %% [markdown]
# #### Vraag 5c: Condensatoren uit het dagelijkse leven
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
# Hieronder is een foto te zien van condensatoren die in het dagelijkse leven gebruikt wordt.
# Print de capaciteiten in deze vraag op een nette en overzichtelijke manier.
# 1. In figuur 5.1 is een condensator te zien van 1 $\micro$F, stel deze condensator kan geapproximeerd worden als een cilinder condensator met binnendiameter 5 mm en een buitendiameter van 6 mm. Bereken wat de lengte van de condensator dan zou zijn.
# Stel dat we een vierkante plaat condensator hebben van 1 $\micro$F.
# 2. Bereken hoe lang de vlakke plaat condensator moet zijn als er 0.5 mm tussen de platen zit en de platen 6 mm breed zijn.

# %% [markdown]
# ![figure 5.1](figures/Condensator_1_uF.jpg)

# %% [markdown]
# ##### Figure: 5.1 Een 1 microfarad condensator.

# %%
###
#1. Determening the length of the capacitor in m
I_r_2 = 2.5e-3 # Inner radius of the cylinder (diameter = 5mm)
O_r_2 = 3e-3 # Outer radius of the cylinder (diameter = 6mm)
C_1 = 1e-6 # Capacitance in F

L_c_2 = C_1 * np.log(O_r_2/I_r_2)/(2*np.pi*epsilon0) # Length of cylinder in m 

print(f"Cylinder length for 1µF (5/6 mm): {L_c_2:.3f} m")

w = 6e-3 # width of plate (m)
d = 0.5e-3 # distance between plate (m)

#2. Determening the length of the plate capacitor in m

C_2 = 1e-6 # Capacitance in F
A = C_2*d/epsilon0 # Area of the plate in m^2

L_p_2 = A/w # Length of the plate in m

print(f"Plate length for 1µF (6 mm width): {L_p_2:.3f} m")
###
# Out:
# Cylinder length for 1µF (5/6 mm): 3277.318 m
# Plate length for 1µF (6 mm width): 9411.942 m

# %% [markdown]
# #### Vraag 5d: Hoge capaciteit condensatoren
#
# 1. Beargumenteer of je antwoorden uit vraag 5c realistisch zijn.
# 2. Bekijk je formule uit vraag 5a en bedenk hoe ze dit binnen in de condensator opgelost hebben.

# %% [markdown]
# ##### Antwoorden 5d
#
# 1. This is extremely unrealistic, as the length of the plates are extremely high. For reference the condensator in the photo is small enough to be measured in mm or cm.
# 2. To obtain a higher capacitance, it can be effective to increase the surface area of the cylindrical plate. Additionally the plate separation for the flat plate sensor the separation can be minimised to increase C again, and in the case of the cylindrical plate reduce the radial gap between the outer and inner radius (b and a). Lastly the permittivity can also be increased. (All these relationships have been established with the use of the base formulas given earlier)

# %% [markdown]
# #### Vraag 5e: Condensator in een achtbaan
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
#
# Met het vak inleidend practicum zijn jullie naar Drievliet gegaan om daar metingen aan de attracties te doen. In Drievliet staat de achtbaan Formule X, deze achtbaan heeft een topsnelheid van 70 $\frac{\text{km}}{\text{h}}$ en bevat een treintje met plek voor 6 mensen. Deze snelheid bereikt de achtbaan door heel snel een karretje weg te schieten, dit wordt gedaan door de treintjes met een lineaire inductie motor te versnellen. Om de impact hiervan op het stroomnet te beperken gebruiken zij een condensator om de energie op te slaan en dan in een keer af te staan aan het treintje. In deze opdracht gaan we kijken wat de afmetingen zouden moeten zijn als ze vlakke plaat condensatoren zouden gebruiken.
#
# De energie die opgeslagen is in een condensator kan berekend worden met de onderstaande formule.
#
# $E = \frac{1}{2} CV^2$
# Hierin is $E$ de totaal opgeslagen energie $C$ de capaciteit en $V$ het voltage waarop de condensator opereert, in dit geval $10$ $kV$.
# 1. Schat de massa van een treintje dat afgeschoten wordt.
# 2. Bereken de totale energie van het treintje na het afschieten.
# 3. Bereken de totale capaciteit van de condensator.
# 4. Bereken het oppervlakte van een vlakke plaat condensator die deze capaciteit heeft als die gevuld is met water en de platen 1 mm van elkaar afstaan.
# 5. Print alle berekende waardes op een nette en overzichtelijke manier.
# 6. Is dit realistisch, bedenk een manier hoe dit toch kan in een relatief klein volume.

# %%
###
# I was not sure whether the question reffered to a train with people or without, so here I just assumed its filled with 6 persons. 

#Estimating mass of train
m_person = 70 # mass of one person (kg)
m_train = 800 # mass of the train (kg)
m_total = 6*m_person + m_train # total mass (kg)

#Kinetic energy of train after launch:
v_train = (70*1000)/3600 # velocity of train (m/s )
E_train = 1/2*m_total*v_train**2 # kinetic energy of the train (J)

#Capacity of capacitor
V = 10000 # voltage (V)
C_tot = E_train*2/(V**2) # Total capacitance (F)

#Area of parallel plate water filled capacitor
d = 1e-3 # distance between plates (m)
epsilon_r_water = 80 # relative permittivity of water 
A_water = C_tot*d/(epsilon0*epsilon_r_water) #area of water filled capacitor (m^2)

print(f"Estimated train mass = {m_train:.0f} kg")
print(f"Launch speed = {v_train:.2f} m/s")
print(f"Kinetic energy of train = {E_train:.3e} J")
print(f"Capacitance = {C_tot:.3e} F")
print(f"Plate area with water = {A_water:.3e} m^2")

# Is it realstic?

print("Realistic? No the plate area with water is way too large in comparison to the capacitance used. It could be possible that they use high epsilon value materials.")


###
# Out:
# Estimated train mass = 800 kg
# Launch speed = 19.44 m/s
# Kinetic energy of train = 2.306e+05 J
# Capacitance = 4.613e-03 F
# Plate area with water = 6.512e+03 m^2
# Realistic? No the plate area with water is way too large in comparison to the capacitance used. It could be possible that they use high epsilon value materials.

# %% [markdown]
# ##### Antwoorden 5e
#
# As printed above, it could be possible by using materials with high epsilon_r values. Additionally when researched its seen that in practice they stack multiple plates and rolling the plates into compact cylinders to reduce volume.

# %% [markdown]
# #### Vraag 5f: Veranderende capaciteit
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt..
#
# 1. Bereken en plot de capaciteit van een vlakke plaat condensator van $10$ bij $10$ $cm$ waarbij de afstand tussen de platen lineair toeneemt van $0.5$ $mm$ tot $5$ $mm$.
# 2. Bereken en plot de capaciteit van een cilinder condensator met een binnendiameter van 9 mm en een buitendiameter van 10 mm en 10 cm lang, waarbij de binnencilinder er langzaam in 10 seconde uitgetrokken wordt.

# %%
###
# Capacitance of a flat plate capacitor
A = 0.1*0.1 # area of plate (m^2)
d_min = 0.5e-3 # minimum distance between plates (m)
d_max = 5e-3 # maximum distance between plates (m)
d_test = np.linspace(d_min,d_max,100) # test points for distances

C_plate_values = epsilon0*A/d_test # Capacitance values for the varying distances

plt.plot(d_test, C_plate_values) # plotting distance (m) and capacitance (F) 
plt.xlabel('Distance between plates (m)')
plt.ylabel('Capacitance (F)')
plt.title('Capacitance of a flat plate capacitor as a function of distance between plates')
plt.grid()
plt.show()

#Capacitance of cylindrical capacitator 
a = (9/2)*1e-3 # inner radius (m)
b = (10/2)*1e-3 # outer radius (m)
max_L = 0.1 # Length of cylinder (m)

t = np.linspace(0, 10, 100)
L_values = np.linspace(max_L, 0, 100)  # length decreases linearly from 0.1 to 0 because its being pulled out

C_cyl_values = 2 * np.pi * epsilon0 * L_values / np.log(b/a) # Capacitance values for varying lengths

plt.plot(t, C_cyl_values, 'r-', linewidth=2)
plt.xlabel('Time (s)')
plt.ylabel('Capacitance (F)')
plt.title('Cylindrical Capacitor - Inner Cylinder Being Pulled Out')
plt.grid()
plt.show()
###

# %% [markdown]
# ## Stop hier met werken tot na de fysieke ontwerpopdracht in week 3.

# %% [markdown]
# ### 6) Reflectie opdracht voor na de fysieke ontwerpopdracht
#
#
# Als het goed is, heeft ieder teamlid van deze simulatie-opdracht een andere opstelling ontworpen hebben tijdens de fysieke ontwerpopdracht. Kies in goed overleg voor deze opdracht een van jullie twee ontwerpen.
#
# Voeg hieronder eerst een foto in van je opstelling die je gekozen hebt.
#
# Jullie gaan in deze opdracht het verschil tussen jullie voorspelde verband en jullie uiteindelijke verkregen kalibratie grafiek proberen te verklaren. Er zijn hiervoor drie mogelijke paden die jullie kunnen kiezen om te onderzoeken, Kies deel a, b of c en werk die volledig uit voor jullie ontwerp. Let op je hoeft er maar een uit te werken.

# %% [markdown]
# Verander de tekst hieronder zodat deze naar jouw foto verwijst. Zorg dat de foto in de map figures staat!
# ![figure 5.1](figures/uiteindelijke_sensor.jpeg)
# ![figure 5.2](figures/uiteindelijke_schets.jpeg)

# %% [markdown]
# #### Vraag 6a: Dunne laag niet meegerekende diëlektricum
# Deze vraag is goed om te kiezen als je in je ontwerp een kleine laag extra materiaal hebt en deze tijdens de ontwerpopdracht niet hebben meegenomen in je theoretisch kalibratie grafiek..
#
# 1. Maak een nieuwe schets van je opstelling waarbij je de dikte van het extra diëlektricum meeneemt.
# 2. Leid de analytische oplossing af van de capaciteit van de hierboven getekende situatie.
# 3. Programmeer de analytische oplossing in python.
# 4. Maak hierna een plot van het kalibratiegrafiek, oude en nieuwe analytische oplossing in een grafiek.
# 5. Beschrijf en verklaar de verschillen tussen de grafieken.

# %% [markdown]
# ##### Antwoorden 6a
#
# *Laat in deze cel je analytische oplossing met schets zien, dit mag met foto's of via LATEX.*

# %%
# Schrijf hier de code voor je oplossing. Gebruik hier je eerder gemaakte functies
# def condensator_extra_laag(#jouw variabelen): # Schrijf hier jouw functie
    ## je functie


### Maak hier je plot

# %% [markdown]
# ##### Antwoorden 6a
#
# *Beschrijf en verklaar je verschillen in deze markdown cel.*

# %% [markdown]
# #### Vraag 6b1: Lading op een condensator met het edge effect meegenomen
#
# In deze opdracht gaan we verder in op het Edge effect en de invloed daarvan op de praktische capaciteit. Deze opdracht bouwt voort op de vraag 4.3.
# Jullie hebben tijdens de ontwerpopdracht vierkante platen gebruikt in tegenstelling tot de ronde platen waarvoor de factoren in figure[label] zijn afgeleid. Er is onderzoek gedaan naar de factoren waarmee de praktische capaciteit vergeleken met de daadwerkelijke capaciteit verschilt dat onderzoek vind je hier: https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=311759. Zoek in het onderzoek tabel 1 en formules 22 en 36 op.
#
# 1. Vergelijk de factor waarmee de schijf(disk) condensator verschilt met die van de vierkante plaat, kunnen we de vierkante plaat factor benaderen met de factor voor een disk condensator? Vergelijk het procentuele verschil tussen de factoren van de circulaire en vierkante platen, met de onzekerheden die in de meting zitten.

# %% [markdown]
# ##### Antwoord 6b1
#
# *Vergelijk hier de factoren tussen de circulaire en vierkante vlakke plaat condensatoren.*

# %% [markdown]
# #### Vraag 6b2: Capaciteit van een condensator met het edge effect meegenomen
#
# Vanaf hier nemen we aan dat factor van de circulaire platen ongeveer gelijk is aan de factor voor vierkante platen. De factor die de capaciteit van de vlakke plaat approximatie linkt aan de werkelijke capaciteit noemen we vanaf nu de idealiteitsfactor.
#
# 1. Bereken de daadwerkelijke theoretische capaciteit van de condensator uit de sanity check 3 van de fysieke ontwerpopdracht en print deze op een nette manier.
# 2. Vergelijk dit met de daadwerkelijke theoretische capaciteit met de capaciteit die je op de dag zelf hebt gemeten.
#
# Vanaf hier gaan we verder met jullie sensor van de ontwerpopdracht "Maak een sensor met condensatoren":
#
# 3. Reken je theoretische kalibratie grafiek om met de idealiteitsfactor.
# 4. Vergelijk je nieuwe theoretische kalibratiegrafiek van je praktische kalibratiegrafiek van de dag zelf.

# %%
# Schrijf hier jouw code die de vlakke plaat capaciteit omschrijft naar de werkelijke capaciteit

# def C_niet_ideaal(#relevante parameters):
    # Jouw berekeningen

# %% [markdown]
# ##### Antwoorden 6b2
#
# *Doe in deze markdown cel je vergelijkingen voor de sanity check condensator en je kalibratiegrafiek.*

# %% [markdown]
# #### Vraag 6c: Niet linear diëlektricum optie 1
#
# Niet alle materialen zijn een lineair diëlektricum. Een aantal van de materialen die sterk niet lineair gedrag vertonen zijn: sponzen, foam & rubber. Als je in je opdracht een materiaal gebruikt heb waarvan je verwacht dat het verband sterk niet lineair is kan dit een hele goede opdracht zijn.
# | Materiaal |$\chi_2$   |
# | :-------------|:-------------|
# | Spons|  |
#
# Als jouw materiaal hier niet tussen staat dan kan je zelf op zoek naar een waarde van $\chi_2$ in de literatuur.

# %% [markdown]
# #### Vraag 6c1
#
# 1. Leidt het D veld van de condensator af uit de wet van Gauss.
# 2. Vindt een analytische uitdrukking voor het elektrisch veld in termen van het D veld.

# %% [markdown]
# ##### Antwoorden 6c 1
# ![Vraag 6c1](vraag_6c1.jpeg)

# %% [markdown]
# #### Vraag 6c2
#
# 1. Programmeer je oplossingen voor het D en E veld in python, gebruik het D veld uit je fysieke ontwerpopdracht.
#
# Als je het elektrische veld van een vierkante vlakke plaat condensator weet kan je de capaciteit berekenen met de onderstaande formule:
# $C = \frac{A
# E_z \epsilon_0}{\Delta V}$
#
# 2. Plot de capaciteit van het niet lineaire diëlektricum, het theoretische kalibratiegrafiek en de uiteindelijke kalibratiegrafiek van de fysieke ontwerpopdracht.
# 3. Verklaar verschillen tussen de grafieken.

# %%
# gegevens: 
epsilon0 = 8.854e-12 # permittiviteit van vacuum (F/m)
A = 0.1 * 0.1 # oppervlakte van de plaat (m^2)
d0 = 0.01 # oorspronkelijke afstand tussen de platen (m)
g = 9.81
V = 4.460 # de gemeten output spanning (V)
x1 = 0.2 # (schatting)
x2 = 0.001 # (schatting)
k = 0.001 # (schatting) bepaalt hoe sterk spons samendrukt per eenheid van druk
m = np.linspace(0, 3.213, 100)  # Massa op de sensor (kg)
m_gemeten = np.array([0, 0.5145, 0.5981, 0.7202, 0.9348, 1.1196, 1.4345, 1.8805, 2.3896, 3.213])

# functie om E_veld te berekenen in de condensator met niet-lineair diëlektricum
def E_condensator(x1, x2, D):
    a = epsilon0 * x2
    b = epsilon0 * (1 + x1)

    discriminant = b**2 + 4*a*D
    E = (2 * D) / (b + np.sqrt(discriminant))  # Oplossen van de kwadratische vergelijking voor E
    
    return E

oplossing_D_veld = (C*V)/A
oplossing_E_veld = E_condensator(x1, x2, oplossing_D_veld)

def d_massa_optie2(m):
    return d0 * np.exp(-k * ((m*g)/A))  # functie voor afstand tussen de platen als functie van de massa op de sensor, met een exponentiële relatie

# functie om capaciteit van het niet lineaire diëlektricum te berekenen:
def C_condensator(A, d, x1, x2, V):
    E = V / d 
    D = epsilon0 * (1 + x1) * E + epsilon0 * x2 * E**2
    Q = D * A
    C = Q / V
    return C

# d_waarden = d_massa(m)
d_waarden = d_massa_optie2(m)
C = C_condensator(A, d_waarden, x1, x2, V)

# theoretische kalibratiegrafiek:
def theoretische_capaciteit(A, d, x1):
    C_theoretisch = (A * epsilon0 * (1 + x1)) / d
    return C_theoretisch

C_theoretisch = theoretische_capaciteit(A, d_waarden, x1)


# Waarden van de capaciteit voor uiteindelijke kalibratiegrafiek van ontwerpopdracht:
F = np.array([51.1, 74.0, 82, 85, 218, 298, 488, 504, 580, 650]) * 1e-12

plt.figure()
plt.ylim(0,1000)
plt.plot(m, C * 1e12, label = "capaciteit van het niet lineaire diëlektricum", color = "red")
plt.xlabel("massa op de sensor (kg)")
plt.ylabel("Capaciteit van de sensor (pF)")
plt.plot(m, C_theoretisch * 1e12, label = "theoretische kalibratiegrafiek", color = "blue", linestyle = "--")
plt.plot(m_gemeten, F * 1e12, ".", label = "kalibratiegrafiek ontwerpopdracht")
plt.title("Capaciteit van de sensor als functie van de massa op de sensor")
plt.errorbar(m_gemeten, F * 1e12, yerr = 10*m_gemeten, fmt="none")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Verschillen tussen de grafieken:
#
# De grafiek voor de capaciteit van het niet lineaire diëlektricum stijgt heel snel bij hogere massa's in vergelijking met de kalibratiegrafiek van de ontwerpopdracht, dit is te verklaren doordat de functie voor de afstand tussen de platen en de massa ervan uitgaat dat de spons oneindig in te drukken is, terwijl normaal het materiaal stijver wordt naarmate je het verder indrukt. De capaciteit gaat daardoor naar oneindig terwijl die eigenlijk moet afvlakken.
#
# Daarnaast is te zien dat zowel de grafiek voor de capaciteit van het niet lineaire diëlektricum en de theoretische kalibratiegrafiek te laag zijn bij de lage massa's. De eerste meting ligt hoger dan de rode en blauwe lijn. Dit komt doordat er ook capaciteit is in bijvoorbeeld de draden en dit is niet meegenomen in de berekening voor de capaciteit.
#
# Ook is te zien dat de grafiek van het niet lineaire diëlektricum sneller stijgt bij grotere massa's dan de theoretische kalibratiegrafiek. Dit komt door epsilon 0 * x2 * E^2 term. Doordat E in het kwadraat is, stijgt de capaciteit heel snel als de afstand tussen de platen klein is (bij grote massa's).

# %% [markdown]
# #### Vraag 7
#
# Hoeveel van de afwijking tussen je metingen en je oorspronkelijke voorspelde kalibratiegrafiek wordt verklaard door wat je bij vraag 6 hebt uitgerekend? Kan je een (aantal) elektrisch veld en capaciteit gerelateerde reden(en) verzinnen wat de rest van de afwijking tussen meting en voorspelde kalibratiegrafiek kan verklaren.

# %% [markdown]
# ##### Antwoorden 7
# The non linear dielectric model from q6 partially explains the deviations between the measurements and theoretical calibration curve.
#
# The theoretical curve (blue dashed line) assumes the dielectric constant is fixed, giving a simple 1/d relationship. The nonlinear model (red curve) accounts for the fact that the material's permittivity changes with electric field strength: ε = ε₀(1+x₁ + x₂·E). This is much closer to reality, which is why the red line follows the measured data points much better than the blue line. But this is only the case in the middle part of the graph (between 1 and 2.5 kg). At low masses both graphs are not a good prediction, both graphs start with a too low capacity. And at high masses the red curve rises very sharply. Question 6 already explains the cause of this.
#
# What could explain the rest of the deviations?
#
# - The formula is assuming that all the electric field lines are confined within the plate lines, while in reality the field bends at the edges. This actually makes the surface area larger. So its possible there is some capacitance that has not been considered by the formula
#
# - The model again (as in most diagrams) assumes that the plates are placed exactly parallel to each other but in reality the sponge may not squish evenly so this could influence the measured d which could influence the capacitance.
#
# - The wire itself has some small amount of capacitance and this is not really accounted for.
